# %%
# Def : Pandas is a Python library used to analyze and manipulate data.

# Helps us to work this : Tables, CSV files, Excel files, Databases, Large datasets

import pandas as pd

# Two main panda data stuctures : series and DataFrame
