# %%
def your_age() :
    try:
        age = int(input("Age: "))
        income = 2000
        rist  = income / age
        print(age)
    except ZeroDivisionError:
        print("Age cannot be divided by zero")
    except ValueError:
        print('Invalid value')
your_age()
# Out:
# Income cannot be divided by zero

# %%
# Classes in Python

class Point:
    def move(self)
