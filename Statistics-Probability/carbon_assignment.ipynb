# %% [markdown]
# ## 27269  USHINDI BIHAME Victoire
# ### Statistic & Probability Assignmennt
# # Carbon Emissions & Population Analysis

# %% [markdown]
# ## Step 1: Import Libraries and Load Dataset

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("carbon.csv")

# Inspect dataset
print(df.columns)
df.head()
df.tail(10)
df.dtypes
df.shape

# %% [markdown]
# Dataset successfully loaded. We inspect structure, types, and size.

# %% [markdown]
# ## Step 2: Data Cleaning

# %%
# Remove duplicates
df = df.drop_duplicates()

# Missing values
print(df.isnull().sum())

# Fill missing values
df = df.fillna(df.mean(numeric_only=True))

# Boxplot
plt.figure()
sns.boxplot(data=df.select_dtypes(include=np.number))
plt.xticks(rotation=90)
plt.title("Outlier Detection")
plt.show()

# %% [markdown]
# Outliers and missing values handled to improve reliability.

# %% [markdown]
# ## Step 3: Create New Variable

# %%
# Create Real_Total_population
df["Real_Total_population"] = df["Total_population"] / 10

df.head()

# %% [markdown]
# ## Step 4: Population Trend

# %%
plt.figure()
plt.plot(df["Year"], df["Real_Total_population"])
plt.title("Population Trend (1961-2015)")
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# Population increases steadily. Rwanda reflects similar growth patterns.

# %% [markdown]
# ## Step 5: Carbon Emission Distribution

# %%
plt.figure()
sns.histplot(df["Avg_Carbon_emmsion_per capita"], kde=True)
plt.title("Carbon Emission Distribution")
plt.show()

# %% [markdown]
# Distribution likely right-skewed: many low emitters, few high emitters.

# %% [markdown]
# ## Step 6: Correlation Analysis

# %%
cols = [
    "Real_Total_population",
    "Avg_Carbon_emmsion_per capita",
    "total_CE_Ktons",
    "cerial_production_MT",
    "avg_Energy_use_kgoe_percapita",
    "avg_temp_change"
]

corr = df[cols].corr()
print(corr)

plt.figure()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Positive correlations show linked growth between population, emissions, and energy use.

# %% [markdown]
# ## Step 7: Relationship Plot

# %%
plt.figure()
sns.scatterplot(x=df["Real_Total_population"], y=df["avg_Energy_use_kgoe_percapita"])
plt.title("Population vs Energy Use")
plt.show()

# %% [markdown]
# Positive relationship: more population → higher energy demand.

# %% [markdown]
# ## Step 8: Regression

# %%
from sklearn.linear_model import LinearRegression

X = df[["Real_Total_population"]]
y = df["avg_Energy_use_kgoe_percapita"]

model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_

print(f"y = {slope}x + {intercept}")

# %% [markdown]
# Regression models relationship between population and energy use.

# %% [markdown]
# ## Step 9: Predictions

# %%
# Rwanda prediction (12 million)
print(model.predict([[12]]))

# Reverse prediction
print((400 - intercept) / slope)
