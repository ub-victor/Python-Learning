# %%
def your_age() :
    try:
        age = int(input("Age: "))
        income = 2000
        rist  = income / age
        print(age)
    except ZeroDivisionError:
        print("Age cannot be divided by zero")
    except ValueError:
        print('Invalid value')
your_age()
# Out:
# Income cannot be divided by zero

# %%
# Classes in Python

class Point:
    def move(self):
        print("Move")
    def draw(self):
        print("draw")


point_1 = Point()
point_1.x = 10
point_1.draw()
point_1.y= 20
point_1.move()
print(point_1.x, point_1.y)
# Out:
# draw
# Move
# 10 20

# %%
# Class with Constructor

class Point:
    def __init__(self, x, y):
            self.x = x
            self.y = y

    def move(self): # the "self" is used to refer to the current instance of the class , which means that it allows you to access the attributes and methods of the class from within
        print("Move")
    def draw(self):
        print("draw")

point = Point(10,20)

print(point.x)
print(point.y)
point.move()
# Out:
# 10
# 20
# Move

# %%
# Quiz
class Person:
    def __init__(self, name):
        self.name = name
    
    def talk (self):
        print(f"Hi, I am {self.name}")

per = Person("Victoire")
per.talk()

per1 = Person("Ushindi")
per1.talk()
# Out:
# Hi, I am Victoire
# Hi, I am Ushindi

# %%
# Inheritance

class Mammal:
    def walk(self):
        print("Walk")


class Dog (Mammal):
    def bark(self):
        print("bark")



class Cat(Mammal ): 
    def be_annoying(self):
        print("annoying")


dog = Dog()
dog.bark()
dog.walk()

print()

cat = Cat()
cat.walk()
cat.be_annoying()
# Out:
# bark
# Walk
#
# Walk
# annoying

# %%
# Modules
# Generating Random Values

import random

for i in range(3):
    print(random.random())
# Out:
# 0.2918014644962621
# 0.6211495928808168
# 0.26997324440560466

# %%
import random

members =  [ "Victoire", "Vick", "Ushindi", "Bihame", "Victor"] 
leader = random.choice(members)
print(leader)
# Out:
# Victoire

# %%
import random
 

class Dice: 
    def roll (self):
        # Simulates rolling a six-sided die (generates a random integer between 1 and 6 inclusive)
        first = random.randint(1,6)
        second = random.randint(1,6)
        return first, second


dice = Dice()
print(dice.roll())
# Out:
# (1, 5)

# %%
# Files and Directories
