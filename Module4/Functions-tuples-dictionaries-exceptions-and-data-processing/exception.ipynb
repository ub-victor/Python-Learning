# %%
def your_age() :
    try:
        age = int(input("Age: "))
        income = 2000
        rist  = income / age
        print(age)
    except ZeroDivisionError:
        print("Income cannot be divided by zero")
    except ValueError:
        print('Invalid value')
your_age()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 9
#       7     except ValueError:
#       8         print('Invalid value')
# ----> 9 your_age()
#
# Cell In[16], line 5, in your_age()
#       3     age = int(input("Age: "))
#       4     income = 2000
# ----> 5     rist  = income / age
#       6     print(age)
#       7 except ValueError:
#
# ZeroDivisionError: division by zero
