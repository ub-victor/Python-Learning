# %% [markdown]
# # Part A - Multiple Choice Question
#
# ### 1. What is machine learning inference?
#     Machine learning inference is the process of using a trained ML model to make predictions on new data
# ### 2. What is a trained model?
#     A trained model is a machine learning model that has already learned patters from training data
# ### 3. What does a .pkl file store?
#     A .pkl file stores serialized Python objects such as trained ML models
# ### 4. What is the role of "joblib.load()"
#     "Joblib.load()" loads a saved machine learing model from dist into memory
# ### 5.  What is a feature in ML?
#     A feature in ML is an input variable used by the model for prediction
# ### 6. What is a label in ML?
#     A label is the expected output or target value in supervided learning
# ### 7. What  does predict_proba() return?
#     predict_proba returns the probability for each class
# ### 8. What type of problem is health risk prediction?
#     The health risk prediction: It is mainly a classification problem
# ### 9.  What doest predict() returns
#     predict() returns predicted class or value
# ### 10. What is classification?
#     Classification is predicting categories or classes
# ### 11. Why is feature order important?
#     The feature order is important: Because the models expects features in the same order used during training.
# ### 12. What happens if a feature is missing?
#     When the feature is missing, The Predication may fail or become inaccurate.
# ### 13. Why use pandas DataFrame?
#     Because it organizes stuctured data into rows and columns
# ### 14. What is Structured data?
#     Structured data  is  Data organized in fixed  format such as table
# ### 15. What is tabular data?
#     Tabular data are Data stored in rows and columns
# ### 16. What is input validation?
#     input validation is checking whether input data is correct and usable
# ### 17. What is Data consistency?
#     Data consistency Ensures data follows the same format and standands
# ###  18. What happens with wrong data types?
#     The model may produce errors or incorrect prediction
# ### 19. What is data  preprocessing
#     Data preprocessing is preparing data before prediction or training
# ### 20. what is a data pipeline?
#     Data pipeline is a sequence of steps for processing data automatically
# ### 21. What is model prediction?
#     Model predication is the output generated by a machine learning model
# ### 22. What is probability output
#     Is the likelihood of each prediction class
# ### 23. What is underfitting ?
#     Underfitting is when a model fails to learn enough from  training data
# ### 24. What is overfitting?
#     Overfitting is when a model memorizes training data and performs poorly on new data.
# ### 25. What is confidence score?
#     Confidence score is a numerical value showing how confident the model is.
# ### 26. What is generalization
#     Is the ability of a model to work well on unseen data
# ### 27. What is predication accuracy?
#     Is the percentage of correct predictions
# ### 28 What is feature importance?
#     Is to measure how much a feature affects prediction.
# ### 29. What is training data?
#     Data used to train the model.
# ### 30. What is  test data?
#     Test data is  used to evaluate model performance

# %% [markdown]
# # Open Ended Questions
#
# ### 31. Explain how the predict_risk() function works.
#     The predict_risk() function receives patient data, converts it into a DataFrame, sends it to the model, gets the prediction, and returns the health risk result
#
# ### 32. Explain the role of joblib.
#     Joblib is used to save and load train ML models efficiently
# ### 33. Explain  feature consistency
#     Feature consistency means using the same features, order, and format during both training and inference.
# ### 34. Explain prediction generation
#     Prediction generation is the process where the model analyzes input data and produces an output.
# ### 35. Explain Classification
#     Classification divides data into categories such as "High Risk" or "Low Risk"
# ### 36. Explain Probabilities in prediction
#     Probabilities in prediction shows the confidence level for each possible class or
#     is the likelihood for each prediction class
# ### 37 Explain DataFrame usage.
#     DataFrame stores data in tabular form and makes Ml input handling easier
# ### 38. Explain model reuse.
#     Model reuse is a trained model that can be saved and reuse without retaining
# ### 39. Explain input validation.
#     Input validation is checking whether the input data is correct and usabe or
#     checks for missing, invalid, or incorrect values before prediction.
# ### 40. Explain ML in healthcare.
#     Ml in healthcare systems predict diseases, analyze patient risks, and support decision-making.
# ### 41. Compere predict() and predict_proba()
#     predict() gives the final class while the
#     predict_proba() gives  probabilities for all classes (it returns the probabilities for each class)
# ### 42. compare training  vs inference.
#     Training teaches the model using data
#     Inference uses the trained model for prediction
# ### 43 . Compare classification vs regression
#     Classificate predicts categories.
#     Regression predicts numerical values.
# ### 44. Compare structured vs unstructured data
#     Structured data is organized in tables.
#     Unstructured data included images, videos, and text.
# ### 45. Compare manual vs automated prediction
#     Manual prediction depends on humans.
#     Automated prediction uses ML models.
# ### 46. Compare batch vs single prediction.
#     Batch prediction processes many records together
#     Single prediction processes one record
# ### 47. Compare probability vs  predication.
#     Probability measured confidence
#     Prediction is the final output
# ### 48. Compare input vs output
#     input is provided data.
#     output is predicting data.
# ### 49. Compare model vs algorithm
#     Model is the trained result
#     Algorithm is the learning method used to make a model
# ### 50. Compare Validation vs preprocessing
#     Validation checks correctness
#     Preprocessing transforms data
# ### 51. Why is feature order critical?
#     Wrong order changes meaning and causes incorrect predictions.
# ### 52. What happens with incorrect data?
#     The system may crash or produce wrong predictions.
# ### 53. Risks of missing features?
#     Prediction become unreliable or impossible
# ### 54. Importance of data quality?
#     High-quality data improves prediction accuracy
# ### 55. Risks of wrong predictions?
#     They may lead to poor healthcare decision
# ### 56. Why probability matters?
#     Because it helps understand model confidence.
# ### 57. Ml model limitations?
#     Models depend on training dara quality and may contain bias
# ### 58. Why human verification?
#     Humans confirm predications before important decisions.
# ### 59. What is bias?
#     Bias is unfair preference or imbalance in model predictions./ is when there is imbalance in the model
# ### 60. ML failure in healthcare?
#     Failures may occur because of poor data, bias, or missing information.

# %% [markdown]
# # Scenario-Based Question
#
# ### 61. SpO2 = 85, expected risk?
#     High risk because oxygen level is dabgerously low
# ### 62. High BP, normal temp, analyze.
#     The patient may still be at moderate or high risk due to hypertension.
# ### 63. Diabetic smoker impact?
#     Risk increases significantly because both factors affect health negatively.
# ### 64. Missing BMI, system response?
#     The system should request the missing value or reject prediction.
# ### 65. Unrealistic values effect?
#     The model may give unreliable predictions.
# ### 66. Young vs elderly risk?
#     Elderly patients usually have higher risk.
# ### 67. All normal values?
#     Prediction will likely be low risk.
# ### 68. Multiple abnormal values?
#     The model will likely predict high risk.
# ### 69. Same input different output?
#     This may happen because of randomness or model inconsistency.
# ### 70. Wrong prediction reasons?
#     Poor data, bias, missing features, or overfitting.
# ### 71. Low oxygen only?
#     Risk may still be high because oxygen is critical.
# ### 72. High BMI only?
#     Risk may increase moderately.
# ### 73. Fever only?
#     Risk depends on severity and other conditions.
# ### 74. All features missing?
#     Prediction cannot be generated.
# ### 75. Incomplete input?
#     The system should validate and reject incomplete data.
# ### 76. Wrong order input?
#     The model may interpret features incorrectly.
# ### 77. Wrong gender encoding?
#     Predictions may become inaccurate.
# ### 78. Biased model effect?
#     Some groups may receive unfair predictions.
# ### 79. Close probabilities meaning?
#     The model is uncertain between classes.
# ### 80. No probability output?
#     The model may not support probability prediction.

# %% [markdown]
# # Part D - Pratical Questions

# %%
# 81. Create DataFrame from dict
import pandas as pd

# Create  dictionary containing patien data

data = {
    "age": 45,
    "bmi": 28,
    "spo2": 95
}

df = pd.DataFrame([data])

print(df)
# Out:
#    age  bmi  spo2
# 0   45   28    95

# %%
# 82. Write prediction function
def predict_risk(model, data):
    # Convert input data into DataFrame
    df = pd.DataFrame([data])

    # make prediction using model
    prediction = model.predict(df)

    # return prediction
    return prediction[0]

# %%
# 83. Load model using joblib
import joblib

# Load training model from file
model = joblib.load("model.pkl")

# Print confirmition
print("Model loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 import joblib
#       4 # Load training model from file
# ----> 5 model = joblib.load("model.pkl")
#       7 # Print confirmition
#       8 print("Model loaded successfully")
#
# File ~/Desktop/My-Project/Python/py312-env/lib/python3.12/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
# ...

# %%
# 84. Print prediction

# Store prediction result
prediction = "High Risk"

# Print prediction 
print ("predictiom: ", prediction)
# Out:
# predictiom:  High Risk

# %%
# 85. Map numeric to label

# Numeric prediction from model
prediction = 1

# Convert numeric value into readable label
label = "High Risk"  if prediction == 1 else "Low Risk"

print(label)
# Out:
# High Risk

# %%
# 86. Check required features
# Required features list
required = ["age", "bmi", "spo2,", "dd"]

# Input data
data = {
    "age": 45, 
    "bmi": 28, 
    "spo2": 96
    }
# Loop through required features
for feature in required:
    if feature not in data:
        print(feature, "is missing")
# Out:
# spo2, is missing
# dd is missing

# %%
# 87. Handle missing features
# Required features
required = ["age", "bmi", "spo2"]

# Input data
data = {"age": 45, "bmi": 28}

# Check for missing features
missing = [f for f in required if f not in data]

# If missing features exist
if missing:

    # Print missing features
    print("Missing:", missing)
# Out:
# Missing: ['spo2']

# %%
# 88. Use try-except

# Start try block
try:

    # Divide by zero example
    result = 10 / 0

# Catch errors
except Exception as e:

    # Print error message
    print("Error:", e)
# Out:
# Error: division by zero

# %%
# 89. Return dictionary output
# Create function
def result():

    # Return dictionary
    return {
        "prediction": "High Risk",
        "probability": 0.92
    }

# Print result
print(result())
# Out:
# {'prediction': 'High Risk', 'probability': 0.92}

# %%
# 90. Format output
# Prediction values
prediction = "High Risk"
probability = 0.91

# Format output message
message = f"Prediction: {prediction}, Probability: {probability}"

# Print formatted message
print(message)
# Out:
# Prediction: High Risk, Probability: 0.91

# %%
# 91. Batch prediction function
# Define batch prediction function
def batch_predict(model, data_list):

    # Convert list into DataFrame
    df = pd.DataFrame(data_list)

    # Predict all records
    predictions = model.predict(df)

    # Return predictions
    return predictions

# %%
# 92. Loop patients
# Patient list
patients = ["John", "Alice", "Mike"]

# Loop through patients
for patient in patients:

    # Print patient name
    print(patient)
# Out:
# John
# Alice
# Mike

# %%
# 93. Store results
# Empty list for results
results = []

# Add result into list
results.append("High Risk")

# Print results
print(results)
# Out:
# ['High Risk']
